# %% [markdown]
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All).
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE", as well as your name and collaborators below:

# %%
NAME = ""
COLLABORATORS = ""

# %% [markdown]
# ---

# %% [markdown]
# pycse exploration
# =================
#
# The pycse package is hosted at https://github.com/jkitchin/pycse.
#
# In this assignment, you will do some exploration of it. The Github repository has a lot of stuff in it; some of it is the python package, and some of it is documentation supporting it.

# %% [markdown]
# # What packages are required to use pycse?
#
# Look in the setup.py file and see what packages are required.

# %% [markdown]
# # What license does this package use?
#
# Describe the license that is used, and what it allows you to do with the code. Give an example of something you are not allowed to do with this code.

# %% [markdown]
# # Clone the package
# You can get your own copy of this repo. Run this command in a shell in the directory where this notebook is:
#
#     git clone https://github.com/jkitchin/pycse.git
#
# this will download a copy of the repository into a folder called pycse in the directory you run that command. After you do that, run this cell to see if the tests pass.

# %%
# %%bash
# cd pycse
# pytest

# %% [markdown]
# # How many contributors?
#
# Run this command in the repo to see how many contributors there are. Explain what you think the results mean.
#
#     git shortlog --summary --numbered --email

# %% [markdown]
# # How old is this package?
#
# A way to find out how old the repo is is to look at the first commit. It is somewhat tricky to do this. This command finds the first commit, then shows the log for it. What year was this repo started?
#
#     git log `git rev-list --max-parents=0 HEAD`

# %% [markdown]
# # Install this package and make an example
#
# Change into the pycse directory and run `pip install .` That should install the package. Show that you did this by making a small example that uses the pycse.polyfit (https://github.com/jkitchin/pycse/blob/master/pycse/PYCSE.py#L25) function.

# %%
# Run this cell to generate a pdf from this notebook
# Click the generated links to preview and download it.
# Report errors to Professor Kitchin
from s23 import pdf
# %pdf
