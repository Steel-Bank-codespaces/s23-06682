# %% [markdown]
# Before you turn this problem in, make sure everything runs as expected. First, **restart the kernel** (in the menubar, select Kernel$\rightarrow$Restart) and then **run all cells** (in the menubar, select Cell$\rightarrow$Run All).
#
# Make sure you fill in any place that says `YOUR CODE HERE` or "YOUR ANSWER HERE", as well as your name and collaborators below:

# %%
NAME = ""
COLLABORATORS = ""

# %% [markdown]
# ---

# %% [markdown]
# # Open Alex bibtex
#
# Build on the Works class we started before and add a new property to get a bibtex entry for a Works item. You should use the bibtexparser library we looked at on Wednesday. The Works class should be in a file at `pkg/s23openalex/works.py`
#
# Create a package called s23openalex that includes the modified class above. Run the cells below to show that it works. You should put the openalex package in a directory called `pkg`. You don't need to worry about the readme, license, tests, etc. Just get a working package that prints out the bibtex entry.

# %%
# This should install the s23openalex package
# !pip install pkg

# %%
! tree pkg

# %%
! cat pkg/s23openalex/works.py

# %%
# This cell should print a formatted bibtex entry for this Works item
from s23openalex import Works
w = Works('https://doi.org/10.1021/acscatal.5b00538')
w.bibtex

# %%
# Run this cell to generate a pdf from this notebook
# Click the generated links to preview and download it.
# Report errors to Professor Kitchin
from s23 import pdf
# %pdf
